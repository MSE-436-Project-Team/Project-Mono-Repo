# %%
import pandas as pd
import numpy as np
from sklearn.multioutput import MultiOutputRegressor
from sklearn.linear_model import Ridge, ElasticNet
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import loguniform
import os
import joblib

# %%
def find_backend_dir(start_path=None):
    """
    Walk up directories from start_path (or cwd) until a folder named 'backend' is found.
    Returns the absolute path to the 'backend' folder.
    """
    if start_path is None:
        start_path = os.getcwd()
    curr_path = os.path.abspath(start_path)
    while True:
        # Check if 'backend' exists in this directory
        candidate = os.path.join(curr_path, "backend")
        if os.path.isdir(candidate):
            return candidate
        # If at filesystem root, stop
        parent = os.path.dirname(curr_path)
        if curr_path == parent:
            break
        curr_path = parent
    raise FileNotFoundError(f"No 'backend' directory found upward from {start_path}")

# Find the backend directory and CSV folder
backend_dir = find_backend_dir()
csv_dir = os.path.join(backend_dir, "CSVs")
models_dir = os.path.join(backend_dir, "Models")

# %%
train = pd.read_csv(csv_dir+"/train_season_features.csv")
test  = pd.read_csv(csv_dir+"/test_season_features.csv")

# %%
target_cols   = [c for c in train.columns if c.startswith("next_")]
feature_cols  = [c for c in train.columns if c not in ["PERSON_ID","SEASON_ID"] + target_cols]

# %%
X_train, X_val, y_train, y_val = train_test_split(
    train[feature_cols], train[target_cols], test_size=0.2, random_state=42
)

# %%
X_test, y_test = test[feature_cols], test[target_cols]

# %%
# Replace all inf/-inf with NaN for ALL splits
for df_ in [X_train, X_val, y_train, y_val, X_test, y_test]:
    df_.replace([np.inf, -np.inf], np.nan, inplace=True)
# Out:
# /var/folders/8z/yxhm1c6x4bvg_s6d6w0cl6_80000gn/T/ipykernel_32610/675919224.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
imputer = SimpleImputer(strategy='median')

# %%
X_train_imputed = pd.DataFrame(imputer.fit_transform(X_train), columns=X_train.columns, index=X_train.index)
X_val_imputed = pd.DataFrame(imputer.transform(X_val), columns=X_val.columns, index=X_val.index)
X_test_imputed = pd.DataFrame(imputer.transform(X_test), columns=X_test.columns, index=X_test.index)

y_train_imputed = pd.DataFrame(imputer.fit_transform(y_train), columns=y_train.columns, index=y_train.index)
y_val_imputed = pd.DataFrame(imputer.transform(y_val), columns=y_val.columns, index=y_val.index)
y_test_imputed = pd.DataFrame(imputer.transform(y_test), columns=y_test.columns, index=y_test.index)

# %%
ridge = MultiOutputRegressor(Ridge(alpha=1.0, random_state=42))
ridge.fit(X_train_imputed, y_train_imputed)
ridge_pred_val = ridge.predict(X_val_imputed)
print("Ridge Validation MAE:", round(mean_absolute_error(y_val_imputed, ridge_pred_val),3),
      "R2:", round(r2_score(y_val_imputed, ridge_pred_val),3))
# Out:
# Ridge Validation MAE: 1.927 R2: 0.692

# %%
enet = MultiOutputRegressor(ElasticNet(alpha=1.0, l1_ratio=0.5, random_state=42, max_iter=10000))
enet.fit(X_train_imputed, y_train_imputed)
enet_pred_val = enet.predict(X_val_imputed)
print("ElasticNet Validation MAE:", round(mean_absolute_error(y_val_imputed, enet_pred_val),3),
      "R2:", round(r2_score(y_val_imputed, enet_pred_val),3))
# Out:
# ElasticNet Validation MAE: 2.016 R2: 0.605

# %%
ridge_pred_test = ridge.predict(X_test_imputed)
print("Ridge Test MAE:", round(mean_absolute_error(y_test_imputed, ridge_pred_test),3),
      "R2:", round(r2_score(y_test_imputed, ridge_pred_test),3))
# Out:
# Ridge Test MAE: 2.027 R2: 0.66

# %%
enet_pred_test = enet.predict(X_test_imputed)
print("ElasticNet Test MAE:", round(mean_absolute_error(y_test_imputed, enet_pred_test),3),
      "R2:", round(r2_score(y_test_imputed, enet_pred_test),3))
# Out:
# ElasticNet Test MAE: 2.087 R2: 0.572

# %%
param_dist = {"estimator__alpha": loguniform(1e-3, 1e3)}
search = RandomizedSearchCV(
    MultiOutputRegressor(Ridge(random_state=42)),
    param_dist, n_iter=30, cv=3, scoring="neg_mean_absolute_error", n_jobs=-1, random_state=42
)
search.fit(X_train_imputed, y_train_imputed)
print("Best alpha:", search.best_params_)
best_ridge = search.best_estimator_
# Out:
# Best alpha: {'estimator__alpha': np.float64(98.77700294007911)}

# %%
# Rebuild Ridge with best α
best_ridge = MultiOutputRegressor(Ridge(alpha=98.77700294007911, random_state=42))
best_ridge.fit(X_train_imputed, y_train_imputed)
# Out:
# MultiOutputRegressor(estimator=Ridge(alpha=98.77700294007911, random_state=42))

# %%
# Validation performance
val_pred = best_ridge.predict(X_val_imputed)
print("Tuned Ridge Val MAE:", round(mean_absolute_error(y_val_imputed, val_pred),3),
      "R2:", round(r2_score(y_val_imputed, val_pred),3))
# Out:
# Tuned Ridge Val MAE: 1.934 R2: 0.688

# %%
# Test performance
test_pred = best_ridge.predict(X_test_imputed)
print("Tuned Ridge Test MAE:", round(mean_absolute_error(y_test_imputed, test_pred),3),
      "R2:", round(r2_score(y_test_imputed, test_pred),3))
# Out:
# Tuned Ridge Test MAE: 2.026 R2: 0.657

# %%
# Extract coefficient matrix: shape (n_stats, n_features)
coefs = np.vstack([est.coef_ for est in best_ridge.estimators_])
# Wrap in DataFrame
coef_df = pd.DataFrame(coefs.T, index=feature_cols, columns=target_cols)

# Show top positive/negative drivers for each target
for target in target_cols:
    print(f"\nTop +ve coefficients for {target}:")
    print(coef_df[target].sort_values(ascending=False).head(10))
    print(f"Top -ve coefficients for {target}:")
    print(coef_df[target].sort_values().head(10))
# Out:
# Top +ve coefficients for next_Points:
# IS_WIN              0.597786
# GAME_EFFICIENCY     0.382867
# DREB                0.300442
# Points_10G_AVG      0.278911
# Points              0.274020
# SEASON_Autumn       0.228646
# FGA                 0.217500
# EXPERIENCE_YEARS    0.209826
# Minutes_10G_AVG     0.192692
# TO_10G_AVG          0.188936
# Name: next_Points, dtype: float64
# Top -ve coefficients for next_Points:
# PF                        -0.349065
# REB_10G_AVG               -0.267286
# AGE                       -0.230859
# OREB                      -0.224842
# 3PA                       -0.222320
# Minutes                   -0.202214
# GAME_EFFICIENCY_10G_AVG   -0.166952
# BMI                       -0.156837
# GAME_EFFICIENCY_5G_AVG    -0.143642
# AST_5G_AVG                -0.130776
# Name: next_Points, dtype: float64
#
# Top +ve coefficients for next_FTM:
# FTM                 0.368246
# FTA                 0.262048
# IS_WIN              0.100056
# Points_10G_AVG      0.072979
# GAME_EFFICIENCY     0.069585
# DREB                0.063656
# TO                  0.056215
# EXPERIENCE_YEARS    0.047149
# TO_10G_AVG          0.042181
# TO_5G_AVG           0.037688
# Name: next_FTM, dtype: float64
# Top -ve coefficients for next_FTM:
# FGM                 -0.158418
# 3PA                 -0.092758
# REB_10G_AVG         -0.090041
# PF                  -0.071522
# BMI                 -0.051357
# POSITION_CATEGORY   -0.051014
# AGE                 -0.047936
# Minutes             -0.036120
# OREB                -0.033294
# REB_5G_AVG          -0.031661
# Name: next_FTM, dtype: float64
#
# Top +ve coefficients for next_FTA:
# FTA                 0.552035
# FTM                 0.225311
# IS_WIN              0.143944
# GAME_EFFICIENCY     0.078436
# TO                  0.070358
# EXPERIENCE_YEARS    0.070076
# DREB                0.065622
# IS_B2B              0.052374
# TO_10G_AVG          0.051680
# TO_5G_AVG           0.047576
# Name: next_FTA, dtype: float64
# Top -ve coefficients for next_FTA:
# 3PA                 -0.101654
# PF                  -0.092847
# REB_10G_AVG         -0.090722
# FGM                 -0.089054
# AGE                 -0.071296
# BMI                 -0.066250
# POSITION_CATEGORY   -0.061391
# Minutes             -0.045588
# IS_PLAYOFFS         -0.041502
# HEIGHT_INCHES       -0.041357
# Name: next_FTA, dtype: float64
#
# Top +ve coefficients for next_FGM:
# IS_WIN              0.218667
# FGM                 0.160611
# GAME_EFFICIENCY     0.142222
# FGA                 0.114425
# Points              0.105744
# DREB                0.104791
# Points_10G_AVG      0.087640
# EXPERIENCE_YEARS    0.077696
# SEASON_Autumn       0.074725
# Minutes_10G_AVG     0.073071
# Name: next_FGM, dtype: float64
# Top -ve coefficients for next_FGM:
# 3PA                       -0.176186
# FTM                       -0.142091
# PF                        -0.119269
# OREB                      -0.088854
# AGE                       -0.088487
# REB_10G_AVG               -0.080452
# Minutes                   -0.075551
# 3PM                       -0.073387
# GAME_EFFICIENCY_10G_AVG   -0.064228
# BMI                       -0.055411
# Name: next_FGM, dtype: float64
#
# Top +ve coefficients for next_FGA:
# FGA                 0.620395
# IS_WIN              0.453825
# GAME_EFFICIENCY     0.191516
# DREB                0.190477
# EXPERIENCE_YEARS    0.180184
# Minutes_10G_AVG     0.153162
# Points              0.147333
# SEASON_Autumn       0.139723
# TO_10G_AVG          0.135717
# SEASON_Winter       0.126494
# Name: next_FGA, dtype: float64
# Top -ve coefficients for next_FGA:
# 3PA                       -0.221675
# AGE                       -0.185887
# OREB                      -0.184362
# Minutes                   -0.178320
# PF                        -0.176860
# GAME_EFFICIENCY_10G_AVG   -0.139347
# REB_10G_AVG               -0.126666
# AST_5G_AVG                -0.096412
# HEIGHT_INCHES             -0.091702
# POSITION_CATEGORY         -0.083365
# Name: next_FGA, dtype: float64
#
# Top +ve coefficients for next_TO:
# TO             0.179502
# TO_10G_AVG     0.179242
# TO_5G_AVG      0.178349
# IS_WIN         0.051971
# AST_10G_AVG    0.034801
# STL            0.030522
# Points         0.030231
# STL_5G_AVG     0.027208
# AST            0.025962
# AST_5G_AVG     0.022566
# Name: next_TO, dtype: float64
# Top -ve coefficients for next_TO:
# GAME_EFFICIENCY_10G_AVG   -0.025442
# 3PA                       -0.023881
# Minutes                   -0.016775
# GAME_EFFICIENCY_5G_AVG    -0.016238
# AGE                       -0.012971
# IS_PLAYOFFS               -0.012082
# POSITION_CATEGORY         -0.011250
# GAMES_LAST_30D            -0.011091
# HEIGHT_INCHES             -0.009752
# SEASON_Spring             -0.008850
# Name: next_TO, dtype: float64
#
# Top +ve coefficients for next_STL:
# STL                        0.168002
# STL_5G_AVG                 0.162895
# STL_10G_AVG                0.159755
# GAME_EFFICIENCY            0.046906
# TO                         0.037710
# TO_5G_AVG                  0.033847
# TO_10G_AVG                 0.032202
# IS_WIN                     0.025570
# GAME_EFFICIENCY_10G_AVG    0.024278
# SEASON_Autumn              0.023478
# Name: next_STL, dtype: float64
# Top -ve coefficients for next_STL:
# BLK             -0.064643
# BLK_10G_AVG     -0.061436
# BLK_5G_AVG      -0.058997
# AST_5G_AVG      -0.050061
# AST             -0.045490
# AST_10G_AVG     -0.045228
# REB_10G_AVG     -0.043565
# REB_5G_AVG      -0.037404
# Points_5G_AVG   -0.032948
# Points          -0.028294
# Name: next_STL, dtype: float64
#
# Top +ve coefficients for next_BLK:
# BLK_10G_AVG         0.146117
# BLK                 0.145591
# BLK_5G_AVG          0.143273
# IS_WIN              0.071981
# GAME_EFFICIENCY     0.052969
# TO_10G_AVG          0.051818
# PF                  0.047879
# TO_5G_AVG           0.039696
# FTA                 0.034564
# EXPERIENCE_YEARS    0.034405
# Name: next_BLK, dtype: float64
# Top -ve coefficients for next_BLK:
# STL              -0.060977
# STL_10G_AVG      -0.060511
# STL_5G_AVG       -0.058817
# Points_10G_AVG   -0.048508
# AST              -0.045181
# REB_10G_AVG      -0.041308
# Minutes          -0.040697
# IS_PLAYOFFS      -0.037227
# AGE              -0.032199
# REB_5G_AVG       -0.030813
# Name: next_BLK, dtype: float64
#
# Top +ve coefficients for next_PF:
# PF                 0.502143
# SEASON_Winter      0.056394
# BLK_10G_AVG        0.047549
# IS_WIN             0.046511
# BLK_5G_AVG         0.043411
# TO                 0.042471
# GAME_EFFICIENCY    0.035372
# TO_5G_AVG          0.030698
# STL                0.030570
# BLK                0.029995
# Name: next_PF, dtype: float64
# Top -ve coefficients for next_PF:
# AST                       -0.038868
# Minutes                   -0.034282
# REB_10G_AVG               -0.032887
# AST_5G_AVG                -0.031395
# Points_10G_AVG            -0.030918
# IS_PLAYOFFS               -0.029482
# Points_5G_AVG             -0.022361
# REB_5G_AVG                -0.014758
# 3PA                       -0.011970
# GAME_EFFICIENCY_10G_AVG   -0.010350
# Name: next_PF, dtype: float64
#
# Top +ve coefficients for next_USAGE_RATE:
# FGA            1.606009
# IS_WIN         0.880526
# TO_10G_AVG     0.620684
# BLK            0.553243
# TO_5G_AVG      0.550505
# BLK_5G_AVG     0.528558
# BLK_10G_AVG    0.513895
# TO             0.506291
# FTA            0.485801
# IS_PLAYOFFS    0.393037
# Name: next_USAGE_RATE, dtype: float64
# Top -ve coefficients for next_USAGE_RATE:
# Minutes                   -0.817207
# 3PA                       -0.663978
# AGE                       -0.480438
# BMI                       -0.464029
# SEASON_Winter             -0.443874
# HEIGHT_INCHES             -0.408860
# OREB                      -0.337263
# GAME_EFFICIENCY_10G_AVG   -0.329915
# AST_10G_AVG               -0.321874
# AST                       -0.181263
# Name: next_USAGE_RATE, dtype: float64
#
# Top +ve coefficients for next_OREB:
# OREB                 0.292652
# REB                  0.102027
# REB_5G_AVG           0.067938
# POSITION_CATEGORY    0.055717
# REB_10G_AVG          0.051569
# SEASON_Winter        0.043910
# GAME_EFFICIENCY      0.036792
# TO                   0.034231
# 3PM                  0.024183
# IS_WIN               0.022657
# Name: next_OREB, dtype: float64
# Top -ve coefficients for next_OREB:
# DREB            -0.190625
# BMI             -0.052008
# HEIGHT_INCHES   -0.045385
# AST_5G_AVG      -0.032432
# 3PA             -0.031801
# Points_5G_AVG   -0.031571
# AST_10G_AVG     -0.024766
# BLK             -0.018662
# SEASON_Autumn   -0.016905
# AGE             -0.016794
# Name: next_OREB, dtype: float64
#
# Top +ve coefficients for next_DREB:
# DREB                0.365446
# REB                 0.152151
# IS_WIN              0.125700
# REB_5G_AVG          0.087279
# FTA                 0.079800
# GAME_EFFICIENCY     0.076405
# SEASON_Winter       0.071490
# REB_10G_AVG         0.071044
# TO                  0.070165
# EXPERIENCE_YEARS    0.064822
# Name: next_DREB, dtype: float64
# Top -ve coefficients for next_DREB:
# OREB            -0.213295
# SEASON_Spring   -0.078807
# Minutes         -0.057907
# AGE             -0.052807
# FTM             -0.051780
# PF              -0.051503
# AST             -0.050343
# AST_5G_AVG      -0.049660
# SEASON_Autumn   -0.034753
# BMI             -0.031543
# Name: next_DREB, dtype: float64
#
# Top +ve coefficients for next_AST:
# AST_10G_AVG         0.240358
# AST_5G_AVG          0.188692
# IS_WIN              0.171622
# AST                 0.164799
# TO_10G_AVG          0.119666
# TO_5G_AVG           0.096842
# TO                  0.081059
# GAME_EFFICIENCY     0.076826
# EXPERIENCE_YEARS    0.039547
# DREB                0.037925
# Name: next_AST, dtype: float64
# Top -ve coefficients for next_AST:
# STL_10G_AVG      -0.086396
# HEIGHT_INCHES    -0.074046
# STL_5G_AVG       -0.070630
# REB_10G_AVG      -0.066618
# Minutes_5G_AVG   -0.063465
# 3PA              -0.058682
# STL              -0.058486
# SEASON_Spring    -0.056483
# OREB             -0.053177
# REB_5G_AVG       -0.041252
# Name: next_AST, dtype: float64
#
# Top +ve coefficients for next_REB:
# REB                0.254178
# DREB               0.174821
# REB_5G_AVG         0.155217
# IS_WIN             0.148357
# REB_10G_AVG        0.122613
# SEASON_Winter      0.115400
# GAME_EFFICIENCY    0.113197
# TO                 0.104396
# FTA                0.100995
# OREB               0.079357
# Name: next_REB, dtype: float64
# Top -ve coefficients for next_REB:
# BMI             -0.083551
# AST_5G_AVG      -0.082092
# AGE             -0.069601
# FTM             -0.064650
# AST             -0.064426
# PF              -0.064066
# SEASON_Spring   -0.063580
# Minutes         -0.059792
# Points_5G_AVG   -0.055786
# 3PA             -0.054500
# Name: next_REB, dtype: float64
#
# Top +ve coefficients for next_Minutes:
# IS_WIN              0.840683
# SEASON_Winter       0.522809
# EXPERIENCE_YEARS    0.421062
# GAME_EFFICIENCY     0.393935
# Minutes_10G_AVG     0.315396
# Points              0.299061
# DREB                0.243946
# IS_STARTER          0.232875
# TO_10G_AVG          0.225010
# TO                  0.184664
# Name: next_Minutes, dtype: float64
# Top -ve coefficients for next_Minutes:
# PF                        -0.427636
# IS_PLAYOFFS               -0.372465
# AGE                       -0.320717
# GAME_EFFICIENCY_10G_AVG   -0.252705
# REB_10G_AVG               -0.219161
# 3PA                       -0.216841
# OREB                      -0.169607
# HEIGHT_INCHES             -0.156556
# GAMES_LAST_30D            -0.151127
# AST_5G_AVG                -0.149374
# Name: next_Minutes, dtype: float64
#
# Top +ve coefficients for next_3PM:
# 3PA                0.222809
# 3PM                0.138285
# SEASON_Autumn      0.060494
# IS_WIN             0.060395
# Points             0.032251
# Points_10G_AVG     0.030652
# GAME_EFFICIENCY    0.028838
# DREB               0.027204
# Minutes_10G_AVG    0.023940
# TO_10G_AVG         0.019640
# Name: next_3PM, dtype: float64
# Top -ve coefficients for next_3PM:
# FTA                      -0.059443
# FGM                      -0.044482
# PF                       -0.039004
# POSITION_CATEGORY        -0.029022
# FGA                      -0.028487
# GAME_EFFICIENCY_5G_AVG   -0.022950
# GAMES_LAST_30D           -0.022692
# FTM                      -0.017070
# REB_10G_AVG              -0.016341
# AST_5G_AVG               -0.015837
# Name: next_3PM, dtype: float64
#
# Top +ve coefficients for next_3PA:
# 3PA                0.635213
# 3PM                0.282053
# IS_WIN             0.162336
# SEASON_Autumn      0.109944
# DREB               0.077357
# Points             0.062088
# GAME_EFFICIENCY    0.057310
# Minutes_10G_AVG    0.053913
# IS_STARTER         0.046236
# TO_10G_AVG         0.045425
# Name: next_3PA, dtype: float64
# Top -ve coefficients for next_3PA:
# FGM                       -0.098631
# POSITION_CATEGORY         -0.088885
# PF                        -0.069693
# FTA                       -0.067506
# Minutes                   -0.065177
# GAMES_LAST_30D            -0.056079
# OREB                      -0.055190
# REB_10G_AVG               -0.042839
# GAME_EFFICIENCY_10G_AVG   -0.037106
# AST_5G_AVG                -0.036303
# Name: next_3PA, dtype: float64
#
# Top +ve coefficients for next_3P%:
# DREB               1.015606
# IS_PLAYOFFS        0.875073
# Points_10G_AVG     0.843328
# IS_WIN             0.797251
# Minutes_10G_AVG    0.644483
# IS_STARTER         0.604611
# FTM                0.560047
# 3PA                0.505184
# GAME_EFFICIENCY    0.457547
# TO                 0.419976
# Name: next_3P%, dtype: float64
# Top -ve coefficients for next_3P%:
# FTA                       -1.367956
# POSITION_CATEGORY         -1.077625
# SEASON_Spring             -0.965251
# 3PM                       -0.884697
# OREB                      -0.881085
# Minutes_5G_AVG            -0.846839
# GAMES_LAST_30D            -0.644858
# SEASON_Winter             -0.516486
# GAME_EFFICIENCY_5G_AVG    -0.438551
# GAME_EFFICIENCY_10G_AVG   -0.400979
# Name: next_3P%, dtype: float64
#
# Top +ve coefficients for next_FT%:
# FTM                        1.879646
# Points_10G_AVG             1.000311
# Minutes                    0.968987
# Points                     0.833439
# DREB                       0.815321
# SEASON_Autumn              0.708690
# SEASON_Spring              0.548173
# AST_10G_AVG                0.481509
# GAME_EFFICIENCY_10G_AVG    0.415871
# AST_5G_AVG                 0.388015
# Name: next_FT%, dtype: float64
# Top -ve coefficients for next_FT%:
# FTA                      -2.139212
# Minutes_5G_AVG           -1.200951
# GAME_EFFICIENCY_5G_AVG   -0.792093
# OREB                     -0.688707
# FGM                      -0.654889
# TO                       -0.617677
# SEASON_Winter            -0.502006
# BLK_5G_AVG               -0.493963
# BLK_10G_AVG              -0.475946
# TO_5G_AVG                -0.385127
# Name: next_FT%, dtype: float64
#
# Top +ve coefficients for next_FG%:
# OREB                 0.752161
# Points_10G_AVG       0.697726
# FGM                  0.583441
# POSITION_CATEGORY    0.482431
# GAME_EFFICIENCY      0.385398
# SEASON_Winter        0.303642
# Minutes              0.257489
# FG%                  0.249444
# Points               0.233483
# REB                  0.223379
# Name: next_FG%, dtype: float64
# Top -ve coefficients for next_FG%:
# FGA                 -1.026138
# FTM                 -0.645314
# 3PA                 -0.538171
# DREB                -0.528782
# Minutes_5G_AVG      -0.400939
# BLK_5G_AVG          -0.339321
# BLK_10G_AVG         -0.334317
# 3PM                 -0.288084
# TRUE_SHOOTING_PCT   -0.263733
# Points_5G_AVG       -0.235673
# Name: next_FG%, dtype: float64
#
# Top +ve coefficients for next_GAME_EFFICIENCY:
# IS_WIN              1.176379
# GAME_EFFICIENCY     0.830607
# DREB                0.536081
# TO_10G_AVG          0.440455
# EXPERIENCE_YEARS    0.437737
# TO                  0.391708
# FTA                 0.360617
# SEASON_Winter       0.339774
# TO_5G_AVG           0.315591
# Minutes_10G_AVG     0.297040
# Name: next_GAME_EFFICIENCY, dtype: float64
# Top -ve coefficients for next_GAME_EFFICIENCY:
# AGE              -0.442303
# 3PA              -0.408524
# REB_10G_AVG      -0.405554
# Minutes          -0.367179
# BMI              -0.366501
# PF               -0.350202
# HEIGHT_INCHES    -0.320664
# OREB             -0.264358
# SEASON_Spring    -0.236933
# GAMES_LAST_30D   -0.157629
# Name: next_GAME_EFFICIENCY, dtype: float64

# %%
joblib.dump(imputer, models_dir+"/median_imputer.joblib")
joblib.dump(best_ridge, models_dir+"/ridge_regression_season_model.joblib")
# Out:
# ['/Users/jeevanparmar/Uni/MSE 436/Project-Mono-Repo/backend/Models/ridge_regression_season_model.joblib']
