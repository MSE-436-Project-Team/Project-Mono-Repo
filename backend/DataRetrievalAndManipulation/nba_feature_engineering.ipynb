# %% [markdown]
# # NBA Data Feature Engineering and Preprocessing
#
# This notebook performs comprehensive feature engineering and data preprocessing on NBA data including:
# - Player information and demographics
# - Career statistics
# - Game-by-game box scores
# - Team information
#
# ## Data Sources:
# - `active_players.csv`: Current NBA player information
# - `career_stats.csv`: Player career statistics by season
# - `boxscores_*.csv`: Game-by-game box scores for multiple seasons
# - `nba_teams.csv`: Team information

# %% [markdown]
# ## 1. Imports and Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
import glob

# Set up plotting style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
warnings.filterwarnings('ignore')

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.width', 1000)

# %% [markdown]
# ## 2. Data Loading and Initial Exploration

# %%
def find_backend_dir(start_path=None):
    """
    Walk up directories from start_path (or cwd) until a folder named 'backend' is found.
    Returns the absolute path to the 'backend' folder.
    """
    if start_path is None:
        start_path = os.getcwd()
    curr_path = os.path.abspath(start_path)
    while True:
        # Check if 'backend' exists in this directory
        candidate = os.path.join(curr_path, "backend")
        if os.path.isdir(candidate):
            return candidate
        # If at filesystem root, stop
        parent = os.path.dirname(curr_path)
        if curr_path == parent:
            break
        curr_path = parent
    raise FileNotFoundError(f"No 'backend' directory found upward from {start_path}")

# Find the backend directory and CSV folder
backend_dir = find_backend_dir()
csv_dir = os.path.join(backend_dir, "CSVs")

# %%
# Load all datasets
print("Loading datasets...")

# Load player data
players_df = pd.read_csv(os.path.join(csv_dir, 'active_players.csv'))
print(f"Players data shape: {players_df.shape}")

# Load career stats
career_stats_df = pd.read_csv(os.path.join(csv_dir, 'career_stats.csv'))
print(f"Career stats shape: {career_stats_df.shape}")

# Load teams data
teams_df = pd.read_csv(os.path.join(csv_dir, 'nba_teams.csv'))
print(f"Teams data shape: {teams_df.shape}")

# Load box scores (we'll load a few recent seasons for demonstration)
boxscore_files = glob.glob(os.path.join(csv_dir, 'boxscores_*.csv'))
print(f"Found {len(boxscore_files)} boxscore files")
# Out:
# Loading datasets...
# Players data shape: (572, 15)
# Career stats shape: (3637, 27)
# Teams data shape: (30, 6)
# Found 22 boxscore files

# %%
recent_boxscores = []
for file in boxscore_files:
    try:
        df = pd.read_csv(file)
        if df.empty:
            print(f"Warning: {file} is empty. Skipping.")
            continue
        season = os.path.basename(file).replace('boxscores_', '').replace('.csv', '')
        
        season = season.replace('_', '-')  # Normalize season format
        df['season'] = season
        recent_boxscores.append(df)
    except Exception as e:
        print(f"Error loading {file}: {e}")

# If columns don't match, take the intersection of all columns
if recent_boxscores:
    all_columns = set.intersection(*(set(df.columns) for df in recent_boxscores))
    print(f"Columns in all boxscores: {all_columns}")
    recent_boxscores = [df[list(all_columns)] for df in recent_boxscores]
    boxscores_df = pd.concat(recent_boxscores, ignore_index=True)
    print(f"Final boxscores shape: {boxscores_df.shape}")
else:
    print("No boxscores loaded.")
# Out:
# Columns in all boxscores: {'FTA', 'season', '3PM', 'REB', 'Result', 'SPI', '+/-', 'Date', 'FGA', 'Minutes', 'FG%', 'PERSON_ID', 'Points', '3PA', 'OREB', 'PF', 'FT%', 'TO', 'Team', '3P%', 'DREB', 'FGM', 'Player', 'BLK', 'FTM', 'STL', 'AST', 'Opponent'}
# Final boxscores shape: (167718, 28)

# %%
# --- PATCH: Standardize PERSON_ID in boxscores to match active_players.csv ---

# 1. Clean up name columns for robust matching
players_df['DISPLAY_FIRST_LAST_clean'] = players_df['DISPLAY_FIRST_LAST'].str.strip().str.lower()
boxscores_df['Player_clean'] = boxscores_df['Player'].str.strip().str.lower()

# 2. Map from cleaned player name to PERSON_ID
name_to_id = dict(zip(players_df['DISPLAY_FIRST_LAST_clean'], players_df['PERSON_ID']))

# 3. Update PERSON_ID in boxscores
boxscores_df['PERSON_ID'] = boxscores_df['Player_clean'].map(name_to_id)

# 4. Optional: add the cleaned display name for merging consistency
boxscores_df['DISPLAY_FIRST_LAST'] = boxscores_df['Player_clean'].map(
    dict(zip(players_df['DISPLAY_FIRST_LAST_clean'], players_df['DISPLAY_FIRST_LAST']))
)

# 5. Clean up temp columns
boxscores_df.drop('Player_clean', axis=1, inplace=True)
players_df.drop('DISPLAY_FIRST_LAST_clean', axis=1, inplace=True)

# 6. Sanity check for unmapped players
unmapped = boxscores_df[boxscores_df['PERSON_ID'].isnull()]['Player'].unique()
if len(unmapped) > 0:
    print(f"WARNING: {len(unmapped)} boxscore players not found in active_players.csv! Examples: {unmapped[:10]}")

# %%
# Display basic information about each dataset
print("=== PLAYERS DATA ===")
print(players_df.info())
print("\nFirst few rows:")
print(players_df.head())

print("\n=== CAREER STATS DATA ===")
print(career_stats_df.info())
print("\nFirst few rows:")
print(career_stats_df.head())

print("\n=== TEAMS DATA ===")
print(teams_df.info())
print("\nFirst few rows:")
print(teams_df.head())

print("\n=== BOXSCORES DATA ===")
print(boxscores_df.info())
print("\nFirst few rows:")
print(boxscores_df.head())
# Out:
# === PLAYERS DATA ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PERSON_ID           572 non-null    int64
#  1   DISPLAY_FIRST_LAST  572 non-null    object
#  2   SCHOOL              571 non-null    object
#  3   TEAM_ID             572 non-null    int64
#  4   TEAM_ABBREVIATION   533 non-null    object
#  5   DRAFT_YEAR          572 non-null    object
#  6   DRAFT_ROUND         571 non-null    object
#  7   DRAFT_NUMBER        570 non-null    object
#  8   FROM_YEAR           572 non-null    int64
#  9   TO_YEAR             572 non-null    int64
#  10  POSITION            572 non-null    object
#  11  HEIGHT              572 non-null    object
#  12  WEIGHT              570 non-null    float64
#  13  BIRTHDATE           572 non-null    object
#  14  CURRENT_AGE         572 non-null    int64
# dtypes: float64(1), int64(5), object(9)
# memory usage: 67.2+ KB
# None
#
# First few rows:
#    PERSON_ID DISPLAY_FIRST_LAST           SCHOOL     TEAM_ID TEAM_ABBREVIATION DRAFT_YEAR DRAFT_ROUND DRAFT_NUMBER  FROM_YEAR  TO_YEAR        POSITION HEIGHT  WEIGHT            BIRTHDATE  CURRENT_AGE
# 0    1630173   Precious Achiuwa          Memphis  1610612752               NYK       2020           1           20       2020     2025         Forward    6-8   243.0  1999-09-19T00:00:00           25
# 1     203500       Steven Adams       Pittsburgh  1610612745               HOU       2013           1           12       2013     2025          Center   6-11   265.0  1993-07-20T00:00:00           31
# 2    1628389        Bam Adebayo         Kentucky  1610612748               MIA       2017           1           14       2017     2025  Center-Forward    6-9   255.0  1997-07-18T00:00:00           27
# 3    1630534       Ochai Agbaji           Kansas  1610612761               TOR       2022           1           14       2022     2025           Guard    6-5   215.0  2000-04-20T00:00:00           25
# 4    1630583       Santi Aldama  Loyola-Maryland  1610612763               MEM       2021           1           30       2021     2025  Forward-Center    7-0   215.0  2001-01-10T00:00:00           24
#
# === CAREER STATS DATA ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3637 entries, 0 to 3636
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          3637 non-null   int64
#  1   SEASON_ID          3637 non-null   object
#  2   LEAGUE_ID          3637 non-null   int64
#  3   TEAM_ID            3637 non-null   int64
#  4   TEAM_ABBREVIATION  3637 non-null   object
#  5   PLAYER_AGE         3637 non-null   float64
#  6   GP                 3637 non-null   int64
#  7   GS                 3637 non-null   int64
#  8   MIN                3637 non-null   float64
#  9   FGM                3637 non-null   int64
#  10  FGA                3637 non-null   int64
#  11  FG_PCT             3637 non-null   float64
#  12  FG3M               3637 non-null   int64
#  13  FG3A               3637 non-null   int64
#  14  FG3_PCT            3637 non-null   float64
#  15  FTM                3637 non-null   int64
#  16  FTA                3637 non-null   int64
#  17  FT_PCT             3637 non-null   float64
#  18  OREB               3637 non-null   int64
#  19  DREB               3637 non-null   int64
#  20  REB                3637 non-null   int64
#  21  AST                3637 non-null   int64
#  22  STL                3637 non-null   int64
#  23  BLK                3637 non-null   int64
#  24  TOV                3637 non-null   int64
#  25  PF                 3637 non-null   int64
#  26  PTS                3637 non-null   int64
# dtypes: float64(5), int64(20), object(2)
# memory usage: 767.3+ KB
# None
#
# First few rows:
#    PLAYER_ID SEASON_ID  LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  GP  GS     MIN  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  PTS
# 0    1630173   2020-21          0  1610612748               MIA        21.0  61   4   737.0  124  228   0.544     0     1    0.000   56  110   0.509    73   135  208   29   20   28   43   91  304
# 1    1630173   2021-22          0  1610612761               TOR        22.0  73  28  1725.0  265  603   0.439    56   156    0.359   78  131   0.595   146   327  473   82   37   41   84  151  664
# 2    1630173   2022-23          0  1610612761               TOR        23.0  55  12  1141.0  196  404   0.485    29   108    0.269   87  124   0.702   100   228  328   50   31   30   59  102  508
# 3    1630173   2023-24          0  1610612761               TOR        24.0  25   0   437.0   78  170   0.459    13    47    0.277   24   42   0.571    50    86  136   44   16   12   29   40  193
# 4    1630173   2023-24          0  1610612752               NYK        24.0  49  18  1187.0  157  299   0.525    13    50    0.260   45   70   0.643   141   210  351   53   30   56   54  103  372
#
# === TEAMS DATA ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            30 non-null     int64
#  1   full_name     30 non-null     object
#  2   abbreviation  30 non-null     object
#  3   nickname      30 non-null     object
#  4   city          30 non-null     object
#  5   state         30 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.5+ KB
# None
#
# First few rows:
#            id             full_name abbreviation   nickname         city          state
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta        Georgia
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston  Massachusetts
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland           Ohio
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans      Louisiana
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago       Illinois
#
# === BOXSCORES DATA ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167718 entries, 0 to 167717
# Data columns (total 29 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   FTA                 167718 non-null  int64
#  1   season              167718 non-null  object
#  2   3PM                 167718 non-null  int64
#  3   REB                 167718 non-null  int64
#  4   Result              167718 non-null  object
#  5   SPI                 167718 non-null  float64
#  6   +/-                 167718 non-null  int64
#  7   Date                167718 non-null  object
#  8   FGA                 167718 non-null  int64
#  9   Minutes             167718 non-null  int64
#  10  FG%                 167718 non-null  object
#  11  PERSON_ID           167718 non-null  int64
#  12  Points              167718 non-null  int64
#  13  3PA                 167718 non-null  int64
#  14  OREB                167718 non-null  int64
#  15  PF                  167718 non-null  int64
#  16  FT%                 167718 non-null  object
#  17  TO                  167718 non-null  int64
#  18  Team                167718 non-null  object
#  19  3P%                 167718 non-null  object
#  20  DREB                167718 non-null  int64
#  21  FGM                 167718 non-null  int64
#  22  Player              167718 non-null  object
#  23  BLK                 167718 non-null  int64
#  24  FTM                 167718 non-null  int64
#  25  STL                 167718 non-null  int64
#  26  AST                 167718 non-null  int64
#  27  Opponent            167718 non-null  object
#  28  DISPLAY_FIRST_LAST  167718 non-null  object
# dtypes: float64(1), int64(18), object(10)
# memory usage: 37.1+ MB
# None
#
# First few rows:
#    FTA   season  3PM  REB Result   SPI  +/-        Date  FGA  Minutes   FG%  PERSON_ID  Points  3PA  OREB  PF  FT%  TO Team   3P%  DREB  FGM                   Player  BLK  FTM  STL  AST     Opponent       DISPLAY_FIRST_LAST
# 0    0  2023-24    0    0      W   0.0   -8  04/14/2024    0        2     -    1631115       0    0     0   0    -   0  MIA     -     0    0         Orlando Robinson    0    0    0    0  MIA vs. TOR         Orlando Robinson
# 1    0  2023-24    0    2      W   7.9   27  04/14/2024    3       10  33.3    1630198       2    2     1   0    -   1  OKC   0.0     1    1               Isaiah Joe    1    0    0    1  OKC vs. DAL               Isaiah Joe
# 2    0  2023-24    1    2      W  10.4   13  04/14/2024    6       12  33.3    1629652       5    4     0   1    -   0  OKC  25.0     2    2            Luguentz Dort    0    0    0    2  OKC vs. DAL            Luguentz Dort
# 3    5  2023-24    0    1      W  25.2   32  04/14/2024   11       16  45.5    1628983      15    4     1   1  100   0  OKC   0.0     0    5  Shai Gilgeous-Alexander    0    5    0    6  OKC vs. DAL  Shai Gilgeous-Alexander
# 4    0  2023-24    1    1      L  14.7  -32  04/14/2024    9       20  11.1     203501       3    6     0   2    -   2  DAL  16.7     1    1         Tim Hardaway Jr.    0    0    0    3    DAL @ OKC         Tim Hardaway Jr.

# %% [markdown]
# ## 3. Data Cleaning and Preprocessing

# %%
# Clean players data
print("Cleaning players data...")

# Convert birthdate to datetime
players_df['BIRTHDATE'] = pd.to_datetime(players_df['BIRTHDATE'])

# Handle missing values
players_df['SCHOOL'] = players_df['SCHOOL'].fillna('Unknown')
players_df['DRAFT_YEAR'] = pd.to_numeric(players_df['DRAFT_YEAR'], errors='coerce')
players_df['DRAFT_ROUND'] = pd.to_numeric(players_df['DRAFT_ROUND'], errors='coerce')
players_df['DRAFT_NUMBER'] = pd.to_numeric(players_df['DRAFT_NUMBER'], errors='coerce')

# Create draft status feature
players_df['DRAFT_STATUS'] = players_df['DRAFT_YEAR'].apply(
    lambda x: 'Drafted' if pd.notna(x) and x != 'Undrafted' else 'Undrafted'
)

# Extract height in inches
def height_to_inches(height_str):
    if pd.isna(height_str) or height_str == '':
        return np.nan
    try:
        feet, inches = map(int, height_str.split('-'))
        return feet * 12 + inches
    except:
        return np.nan

players_df['HEIGHT_INCHES'] = players_df['HEIGHT'].apply(height_to_inches)

# Create position categories
def categorize_position(position):
    if pd.isna(position):
        return 'Unknown'
    position = str(position).upper()
    if 'GUARD' in position:
        return 'Guard'
    elif 'FORWARD' in position:
        return 'Forward'
    elif 'CENTER' in position:
        return 'Center'
    else:
        return 'Other'

players_df['POSITION_CATEGORY'] = players_df['POSITION'].apply(categorize_position)

# One-hot encode the positions
position_dummies = pd.get_dummies(players_df['POSITION_CATEGORY'], prefix='POS')
players_df = pd.concat([players_df, position_dummies], axis=1)

print(f"Players data cleaned. Shape: {players_df.shape}")
print("\nPosition distribution:")
print(players_df['POSITION_CATEGORY'].value_counts())
# Out:
# Cleaning players data...
# Players data cleaned. Shape: (572, 21)
#
# Position distribution:
# POSITION_CATEGORY
# Guard      287
# Forward    231
# Center      54
# Name: count, dtype: int64

# %%
# Clean career stats data
print("Cleaning career stats data...")

# Convert season to year format
career_stats_df['SEASON_YEAR'] = career_stats_df['SEASON_ID'].str[:4].astype(int)

# Calculate per-game statistics
career_stats_df['PPG'] = career_stats_df['PTS'] / career_stats_df['GP']
career_stats_df['RPG'] = career_stats_df['REB'] / career_stats_df['GP']
career_stats_df['APG'] = career_stats_df['AST'] / career_stats_df['GP']
career_stats_df['SPG'] = career_stats_df['STL'] / career_stats_df['GP']
career_stats_df['BPG'] = career_stats_df['BLK'] / career_stats_df['GP']
career_stats_df['TOPG'] = career_stats_df['TOV'] / career_stats_df['GP']
career_stats_df['MPG'] = career_stats_df['MIN'] / career_stats_df['GP']

# Calculate efficiency metrics
career_stats_df['TS_PCT'] = career_stats_df['PTS'] / (2 * (career_stats_df['FGA'] + 0.44 * career_stats_df['FTA']))
career_stats_df['AST_TO_RATIO'] = career_stats_df['AST'] / career_stats_df['TOV'].replace(0, 1)

# Handle infinite values
career_stats_df = career_stats_df.replace([np.inf, -np.inf], np.nan)

print(f"Career stats cleaned. Shape: {career_stats_df.shape}")
# Out:
# Cleaning career stats data...
# Career stats cleaned. Shape: (3637, 37)

# %%
# Clean boxscores data
print("Cleaning boxscores data...")

# Convert date to datetime
boxscores_df['Date'] = pd.to_datetime(boxscores_df['Date'])

# Convert numeric columns
numeric_columns = ['Minutes', 'Points', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%', 
                   'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST', 'TO', 'STL', 'BLK', 'PF', '+/-', 'SPI']

for col in numeric_columns:
    if col in boxscores_df.columns:
        boxscores_df[col] = pd.to_numeric(boxscores_df[col], errors='coerce')

# Handle percentage columns that might have '-' values
percentage_columns = ['FG%', '3P%', 'FT%']
for col in percentage_columns:
    if col in boxscores_df.columns:
        boxscores_df[col] = boxscores_df[col].replace('-', np.nan)
        boxscores_df[col] = pd.to_numeric(boxscores_df[col], errors='coerce')

# Extract game result (W/L)
boxscores_df['GAME_RESULT'] = boxscores_df['Result'].str[0]

# Create season year from season string
boxscores_df['SEASON_YEAR'] = boxscores_df['season'].str[:4].astype(int)

print(f"Boxscores cleaned. Shape: {boxscores_df.shape}")
print(f"Date range: {boxscores_df['Date'].min()} to {boxscores_df['Date'].max()}")
# Out:
# Cleaning boxscores data...
# Boxscores cleaned. Shape: (167718, 31)
# Date range: 2003-10-29 00:00:00 to 2025-04-13 00:00:00

# %%
# Creating game IDs
boxscores_df['GAME_ID'] = (
    boxscores_df['Date'].astype(str) + '_' +
    boxscores_df['Team'].astype(str) + '_' +
    boxscores_df['Opponent'].astype(str)
)

# %% [markdown]
# ## 4. Feature Engineering

# %%
# Create player-level features
print("Creating player-level features...")

# Age features
players_df['AGE'] = (pd.Timestamp.now() - players_df['BIRTHDATE']).dt.days / 365.25
players_df['AGE_SQ'] = players_df['AGE'] ** 2
players_df['EXPERIENCE_YEARS'] = pd.Timestamp.now().year - players_df['FROM_YEAR']

# Rookie and veteran flag (you can adjust the threshold)
players_df['IS_ROOKIE'] = (players_df['EXPERIENCE_YEARS'] == 0).astype(int)
players_df['IS_VETERAN'] = (players_df['EXPERIENCE_YEARS'] >= 5).astype(int)

# Height and weight features
players_df['BMI'] = (players_df['WEIGHT'] * 0.453592) / ((players_df['HEIGHT_INCHES'] * 0.0254) ** 2)

# Draft features
players_df['DRAFT_POSITION'] = players_df['DRAFT_ROUND'] * 30 + players_df['DRAFT_NUMBER']
players_df['TOP_10_PICK'] = (players_df['DRAFT_POSITION'] <= 10).astype(int)
players_df['LOTTERY_PICK'] = (players_df['DRAFT_POSITION'] <= 14).astype(int)

# Team features
players_df['HAS_TEAM'] = (players_df['TEAM_ID'] != 0).astype(int)

print(f"Player features created. Shape: {players_df.shape}")
# Out:
# Creating player-level features...
# Player features created. Shape: (572, 31)

# %%
# Create career-level features
print("Creating career-level features...")

# Calculate career averages for each player
career_averages = career_stats_df.groupby('PLAYER_ID').agg({
    'PPG': 'mean', 'RPG': 'mean', 'APG': 'mean', 'SPG': 'mean', 'BPG': 'mean',
    'TOPG': 'mean', 'MPG': 'mean', 'TS_PCT': 'mean', 'AST_TO_RATIO': 'mean',
    'GP': 'sum', 'PTS': 'sum', 'REB': 'sum', 'AST': 'sum', 'STL': 'sum', 'BLK': 'sum',
    'SEASON_YEAR': ['min', 'max', 'count']
}).round(3)

# Flatten column names
career_averages.columns = ['_'.join(col).strip() for col in career_averages.columns]
career_averages = career_averages.reset_index()

# Rename columns for clarity
career_averages = career_averages.rename(columns={
    'SEASON_YEAR_min': 'FIRST_SEASON',
    'SEASON_YEAR_max': 'LAST_SEASON',
    'SEASON_YEAR_count': 'SEASONS_PLAYED'
})

# Calculate career totals and averages
career_averages['CAREER_PTS'] = career_averages['PTS_sum']
career_averages['CAREER_REB'] = career_averages['REB_sum']
career_averages['CAREER_AST'] = career_averages['AST_sum']
career_averages['CAREER_STL'] = career_averages['STL_sum']
career_averages['CAREER_BLK'] = career_averages['BLK_sum']

print(f"Career features created. Shape: {career_averages.shape}")
print("\nCareer averages sample:")
print(career_averages.head())
# Out:
# Creating career-level features...
# Career features created. Shape: (568, 24)
#
# Career averages sample:
#    PLAYER_ID  PPG_mean  RPG_mean  APG_mean  SPG_mean  BPG_mean  TOPG_mean  MPG_mean  TS_PCT_mean  AST_TO_RATIO_mean  GP_sum  PTS_sum  REB_sum  AST_sum  STL_sum  BLK_sum  FIRST_SEASON  LAST_SEASON  SEASONS_PLAYED  CAREER_PTS  CAREER_REB  CAREER_AST  CAREER_STL  CAREER_BLK
# 0       2544    27.006     7.547     7.426     1.477     0.730      3.509    37.581        0.592              2.118    1562    42184    11731    11584     2345     1150          2003         2024              22       42184       11731       11584        2345        1150
# 1     101108    16.964     4.413     9.206     1.994     0.167      2.279    33.637        0.580              4.091    1354    23011     5978    12499     2717      222          2005         2024              20       23011        5978       12499        2717         222
# 2     200768    12.425     3.927     5.553     1.207     0.294      2.052    29.544        0.567              2.774    1310    17427     5344     7627     1627      389          2006         2024              23       17427        5344        7627        1627         389
# 3     200782     5.236     4.678     1.084     0.929     0.295      0.758    25.026        0.539              1.438    1050     6648     5538     1401     1114      309          2006         2024              20        6648        5538        1401        1114         309
# 4     201142    27.256     6.929     4.450     0.963     1.168      3.140    36.247        0.631              1.428    1170    31937     8141     5143     1208     1340          2007         2024              19       31937        8141        5143        1208        1340

# %%
# Create game-level features
print("Creating game-level features...")

# Efficiency metrics
boxscores_df['GAME_EFFICIENCY'] = boxscores_df['Points'] + (boxscores_df['REB'] * 1.2) + (boxscores_df['AST'] * 1.5) + (boxscores_df['STL'] * 2) + (boxscores_df['BLK'] * 2) - (boxscores_df['TO'] * 1)

# Shooting efficiency
boxscores_df['TRUE_SHOOTING_PCT'] = boxscores_df['Points'] / (2 * (boxscores_df['FGA'] + 0.44 * boxscores_df['FTA']))

# Usage rate approximation
boxscores_df['USAGE_RATE'] = (boxscores_df['FGA'] + 0.44 * boxscores_df['FTA'] + boxscores_df['TO']) / boxscores_df['Minutes'] * 100

# Game context features
boxscores_df['IS_WIN'] = (boxscores_df['GAME_RESULT'] == 'W').astype(int)
boxscores_df['IS_HOME'] = boxscores_df['Result'].str.contains('vs.').astype(int)

# Season and month features
boxscores_df['MONTH'] = boxscores_df['Date'].dt.month
boxscores_df['DAY_OF_WEEK'] = boxscores_df['Date'].dt.dayofweek
boxscores_df['IS_PLAYOFFS'] = (boxscores_df['MONTH'] >= 4).astype(int)  # Simplified playoff detection

# --- Seasonality Feature ---
def get_season(month):
    if month in [10, 11]:
        return 'Autumn'
    elif month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    else:
        return 'Offseason'

boxscores_df['SEASONAL_PERIOD'] = boxscores_df['MONTH'].apply(get_season)

# One-hot encode for modeling:
seasonal_dummies = pd.get_dummies(boxscores_df['SEASONAL_PERIOD'], prefix='SEASON')
boxscores_df = pd.concat([boxscores_df, seasonal_dummies], axis=1)


print(f"Game features created. Shape: {boxscores_df.shape}")
# Out:
# Creating game-level features...
# Game features created. Shape: (167718, 45)

# %%
# Create rolling average features for players
print("Creating rolling average features...")

# Sort by player and date
boxscores_df = boxscores_df.sort_values(['PERSON_ID', 'Date'])

# Calculate rolling averages for key metrics
rolling_features = ['Points', 'REB', 'AST', 'STL', 'BLK', 'TO', 'Minutes', 'GAME_EFFICIENCY']

for feature in rolling_features:
    if feature in boxscores_df.columns:
        # 5-game rolling average
        boxscores_df[f'{feature}_5G_AVG'] = boxscores_df.groupby('PERSON_ID')[feature].rolling(
            window=5, min_periods=1).mean().reset_index(0, drop=True)
        
        # 10-game rolling average
        boxscores_df[f'{feature}_10G_AVG'] = boxscores_df.groupby('PERSON_ID')[feature].rolling(
            window=10, min_periods=1).mean().reset_index(0, drop=True)

print(f"Rolling features created. Shape: {boxscores_df.shape}")
# Out:
# Creating rolling average features...
# Rolling features created. Shape: (167718, 61)

# %%
# A "starter" is anyone who plays >= 24 minutes (adjust this if you have actual starter info)
boxscores_df['IS_STARTER'] = boxscores_df['Minutes'] >= 24

# Rolling percent of games started (over the season to date)
boxscores_df['START_PCT_SEASON'] = (
    boxscores_df.groupby(['PERSON_ID', 'season'])['IS_STARTER']
    .transform(lambda x: x.expanding().mean())
)

# %%
boxscores_df = boxscores_df.sort_values(['PERSON_ID', 'Date'])

# Days since last game
boxscores_df['PREV_GAME_DATE'] = boxscores_df.groupby('PERSON_ID')['Date'].shift(1)
boxscores_df['DAYS_SINCE_LAST_GAME'] = (boxscores_df['Date'] - boxscores_df['PREV_GAME_DATE']).dt.days

# Back-to-back games flag
boxscores_df['IS_B2B'] = boxscores_df['DAYS_SINCE_LAST_GAME'] == 1

# Rolling count of games in last 30 days (recent workload)
games_last_30d = (
    boxscores_df
    .groupby('PERSON_ID')
    .rolling('30D', on='Date')['GAME_ID']  # or use ['Date'] if you want
    .count()
    .reset_index(drop=True)  
)
boxscores_df['GAMES_LAST_30D'] = games_last_30d

# %% [markdown]
# ## 5. Data Merging and Integration

# %%
# Merge all datasets
print("Merging datasets...")

# Merge players with career averages
players_with_career = players_df.merge(
    career_averages, 
    left_on='PERSON_ID', 
    right_on='PLAYER_ID', 
    how='left'
)

# Merge with teams data
players_with_career = players_with_career.merge(
    teams_df, 
    left_on='TEAM_ID', 
    right_on='id', 
    how='left', 
    suffixes=('', '_team')
)

# Merge boxscores with player info
boxscores_with_players = boxscores_df.merge(
    players_with_career[['PERSON_ID', 'DISPLAY_FIRST_LAST', 'POSITION_CATEGORY', 
                         'AGE', 'EXPERIENCE_YEARS', 'HEIGHT_INCHES', 'WEIGHT', 'BMI',
                         'DRAFT_POSITION', 'TOP_10_PICK', 'LOTTERY_PICK']], 
    on='PERSON_ID', 
    how='left'
)

print(f"Final merged dataset shape: {boxscores_with_players.shape}")
print(f"Number of unique players: {boxscores_with_players['PERSON_ID'].nunique()}")
print(f"Date range: {boxscores_with_players['Date'].min()} to {boxscores_with_players['Date'].max()}")
# Out:
# Merging datasets...
# Final merged dataset shape: (167718, 77)
# Number of unique players: 568
# Date range: 2003-10-29 00:00:00 to 2025-04-13 00:00:00

# %%
boxscores_df = boxscores_df.sort_values(['PERSON_ID', 'Date'])

# Aggregate average stats per player per season
season_stats = (
    boxscores_df.groupby(['PERSON_ID', 'season'])[['Points', 'Minutes', 'REB', 'AST', 'STL', 'BLK', 'TO']]
    .mean().reset_index()
)

# Calculate previous season's points per game for each player
season_stats['PPG_LAG1'] = season_stats.groupby('PERSON_ID')['Points'].shift(1)
season_stats['PPG_DIFF'] = season_stats['Points'] - season_stats['PPG_LAG1']

# Merge back to boxscores_df (if desired, merge on PERSON_ID and season)
boxscores_df = boxscores_df.merge(
    season_stats[['PERSON_ID', 'season', 'PPG_LAG1', 'PPG_DIFF']],
    on=['PERSON_ID', 'season'],
    how='left'
)

# %% [markdown]
# ## 6. Feature Selection and Final Dataset

# %%
# Select final features for modeling
print("Selecting final features...")

feature_columns = [
    # Player demographics
    'AGE', 'AGE_SQ', 'EXPERIENCE_YEARS', 'HEIGHT_INCHES', 'WEIGHT', 'BMI',
    'DRAFT_POSITION', 'TOP_10_PICK', 'LOTTERY_PICK', 'IS_ROOKIE', 'IS_VETERAN',

    # Position (numeric and dummies)
    'POSITION_CATEGORY', 'POS_Guard', 'POS_Forward', 'POS_Center', 'POS_Other',

    # Career averages
    'PPG_mean', 'RPG_mean', 'APG_mean', 'SPG_mean', 'BPG_mean',
    'TOPG_mean', 'MPG_mean', 'TS_PCT_mean', 'AST_TO_RATIO_mean',
    'SEASONS_PLAYED',

    # Career trajectory
    'PPG_LAG1', 'PPG_DIFF',

    # Opportunity & Role
    'IS_STARTER', 'START_PCT_SEASON',

    # Game context
    'IS_HOME', 'IS_WIN', 'MONTH', 'DAY_OF_WEEK', 'IS_PLAYOFFS',

    # Seasonality
    'SEASONAL_PERIOD', 'SEASON_Autumn', 'SEASON_Winter', 'SEASON_Spring',

    # Rolling averages
    'Points_5G_AVG', 'REB_5G_AVG', 'AST_5G_AVG', 'STL_5G_AVG', 'BLK_5G_AVG',
    'TO_5G_AVG', 'Minutes_5G_AVG', 'GAME_EFFICIENCY_5G_AVG',
    'Points_10G_AVG', 'REB_10G_AVG', 'AST_10G_AVG', 'STL_10G_AVG', 'BLK_10G_AVG',
    'TO_10G_AVG', 'Minutes_10G_AVG', 'GAME_EFFICIENCY_10G_AVG',

    # Current game stats
    'Minutes', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%', 'FTM', 'FTA', 'FT%',
    'OREB', 'DREB', 'REB', 'AST', 'TO', 'STL', 'BLK', 'PF',

    # Efficiency metrics
    'GAME_EFFICIENCY', 'TRUE_SHOOTING_PCT', 'USAGE_RATE',

    # Rest/Injury
    'DAYS_SINCE_LAST_GAME', 'IS_B2B', 'GAMES_LAST_30D',

    # Interaction terms
    'AGE_x_MINUTES', 'USAGE_RATE_x_GAME_EFFICIENCY',
]


# Create final dataset
final_features = [col for col in feature_columns if col in boxscores_with_players.columns]
final_dataset = boxscores_with_players[['PERSON_ID', 'Player', 'Date', 'season', 'Points'] + final_features].copy()

# Remove rows with too many missing values
# final_dataset = final_dataset.dropna(thresh=len(final_features) * 0.7)

print(f"Final dataset shape: {final_dataset.shape}")
print(f"Features included: {len(final_features)}")
print(f"Missing values per column:")
print(final_dataset[final_features].isnull().sum().sort_values(ascending=False).head(10))
# Out:
# Selecting final features...
# Final dataset shape: (167718, 65)
# Features included: 60
# Missing values per column:
# FT%                     61956
# 3P%                     36475
# DRAFT_POSITION          20084
# FG%                      5412
# TRUE_SHOOTING_PCT        4769
# DAYS_SINCE_LAST_GAME      568
# USAGE_RATE                418
# WEIGHT                     80
# BMI                        80
# FTM                         0
# dtype: int64

# %%
position_map = {
    'Guard': 1,
    'Forward': 3,
    'Center': 5
}
final_dataset['POSITION_CATEGORY'] = final_dataset['POSITION_CATEGORY'].map(position_map).fillna(0).astype(int)

# %%
final_dataset['DAYS_SINCE_LAST_GAME'] = final_dataset['DAYS_SINCE_LAST_GAME'].fillna(0)

# %% [markdown]
# ## 7. Data Cleansing and Post Processing

# %% [markdown]
# ### 7.1. Check missing‐value rates

# %%
missing_pct = final_dataset[final_features].isna().mean().sort_values(ascending=False)
print(missing_pct[missing_pct > 0].head(20))
# Out:
# FT%                  0.369406
# 3P%                  0.217478
# DRAFT_POSITION       0.119749
# FG%                  0.032268
# TRUE_SHOOTING_PCT    0.028435
# USAGE_RATE           0.002492
# WEIGHT               0.000477
# BMI                  0.000477
# dtype: float64

# %%
to_drop_missing = missing_pct[missing_pct > 0.5].index.tolist()
print("Dropping high-missing features:", to_drop_missing)
final_features = [f for f in final_features if f not in to_drop_missing]
# Out:
# Dropping high-missing features: []

# %% [markdown]
# ### 7.2. Check for zero or near-zero variance

# %%
unique_counts = final_dataset[final_features].nunique().sort_values()
print(unique_counts[unique_counts <= 1])  # truly constant features
# Out:
# IS_HOME         1
# TOP_10_PICK     1
# LOTTERY_PICK    1
# dtype: int64

# %% [markdown]
# - Not dropping any because it makes sense for these to not have variance (binary variables)

# %% [markdown]
# ### 7.3. Correlation filter

# %%
# Only use numeric features for correlation analysis
numeric_features = final_dataset[final_features].select_dtypes(include=[np.number]).columns.tolist()

corr = final_dataset[numeric_features].corr().abs()
upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))

# %%
# Find pairs above 0.95
to_drop_corr = [column for column in upper.columns if any(upper[column] > 0.95)]
print("highly-correlated features:", to_drop_corr)
# Out:
# highly-correlated features: ['Points_10G_AVG', 'REB_10G_AVG', 'AST_10G_AVG', 'Minutes_10G_AVG', 'GAME_EFFICIENCY_10G_AVG', 'FTA']

# %% [markdown]
# - Not dropping because it makes sense for these to be correlated

# %% [markdown]
# ## Saving Final DF to CSV

# %%
# Make Person ID an integer
final_dataset['PERSON_ID'] = final_dataset['PERSON_ID'].astype(int)

# %%
final_dataset.head()
# Out:
#    PERSON_ID        Player       Date   season  Points        AGE  EXPERIENCE_YEARS  HEIGHT_INCHES  WEIGHT        BMI  DRAFT_POSITION  TOP_10_PICK  LOTTERY_PICK  POSITION_CATEGORY  IS_STARTER  START_PCT_SEASON  IS_HOME  IS_WIN  MONTH  DAY_OF_WEEK  IS_PLAYOFFS SEASONAL_PERIOD  SEASON_Autumn  SEASON_Winter  SEASON_Spring  Points_5G_AVG  REB_5G_AVG  AST_5G_AVG  STL_5G_AVG  BLK_5G_AVG  TO_5G_AVG  Minutes_5G_AVG  GAME_EFFICIENCY_5G_AVG  Points_10G_AVG  REB_10G_AVG  AST_10G_AVG  STL_10G_AVG  BLK_10G_AVG  TO_10G_AVG  Minutes_10G_AVG  GAME_EFFICIENCY_10G_AVG  Minutes  FGM  FGA   FG%  3PM  3PA   3P%  FTM  FTA    FT%  OREB  DREB  REB  AST  TO  STL  BLK  PF  GAME_EFFICIENCY  TRUE_SHOOTING_PCT  USAGE_RATE  DAYS_SINCE_LAST_GAME  IS_B2B  GAMES_LAST_30D
# 0       2544  LeBron James 2003-10-29  2003-04      25  40.517454                22             81   250.0  26.789705            31.0            0             0                  3        True               1.0        0       0     10            2            1          Autumn           True          False          False          25.00    6.000000    9.000000        0.00    2.000000   4.000000       42.000000                   45.70           25.00     6.000000     9.000000         0.00     2.000000    4.000000        42.000000                    45.70       42   12   20  60.0    0    2   0.0    1    3   33.3     2     4    6    9   4    0    2   3             45.7           0.586304   60.285714                   0.0   False            13.0
# 1       2544  LeBron James 2003-10-30  2003-04      21  40.517454                22             81   250.0  26.789705            31.0            0             0                  3        True               1.0        0       0     10            3            1          Autumn           True          False          False          23.00    9.000000    8.500000        0.00    4.500000   2.500000       41.500000                   53.05           23.00     9.000000     8.500000         0.00     4.500000    2.500000        41.500000                    53.05       41    8   17  47.1    1    5  20.0    4    7   57.1     2    10   12    8   1    0    7   1             60.4           0.522908   51.414634                   1.0    True            12.0
# 2       2544  LeBron James 2003-11-01  2003-04       8  40.517454                22             81   250.0  26.789705            31.0            0             0                  3        True               1.0        0       0     11            5            1          Autumn           True          False          False          18.00    7.333333    7.666667        0.00    3.666667   2.333333       40.666667                   43.30           18.00     7.333333     7.666667         0.00     3.666667    2.333333        40.666667                    43.30       39    3   12  25.0    0    1   0.0    2    2  100.0     0     4    4    6   2    0    2   3             23.8           0.310559   38.153846                   2.0   False            11.0
# 3       2544  LeBron James 2003-11-05  2003-04       7  40.517454                22             81   250.0  26.789705            31.0            0             0                  3        True               1.0        0       0     11            2            1          Autumn           True          False          False          15.25    8.250000    7.500000        0.75    3.250000   2.250000       40.750000                   42.15           15.25     8.250000     7.500000         0.75     3.250000    2.250000        40.750000                    42.15       41    3   11  27.3    0    2   0.0    1    1  100.0     2     9   11    7   2    3    2   1             38.7           0.305944   32.780488                   4.0   False            10.0
# 4       2544  LeBron James 2003-11-07  2003-04      23  40.517454                22             81   250.0  26.789705            31.0            0             0                  3        True               1.0        0       0     11            4            1          Autumn           True          False          False          16.80    7.600000    6.600000        0.60    4.000000   1.800000       41.400000                   43.22           16.80     7.600000     6.600000         0.60     4.000000    1.800000        41.400000                    43.22       44    8   18  44.4    1    2  50.0    6    7   85.7     0     5    5    3   0    0    7   2             47.5           0.545541   47.909091                   2.0   False             9.0

# %%
# Save the final dataset to CSV
output_file = os.path.join(csv_dir, 'final_nba_dataset.csv')
final_dataset.to_csv(output_file, index=False)
